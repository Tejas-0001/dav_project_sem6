# %% [markdown]
# # ✨ Deepdive into floral distribution
#
# ##### A Data Analysis and Visualization Project under the Guidance of Dr. Prashant Domadia
#
# ###### by Tejas Raj
#
# ---

# %% [markdown]
# ## Introduction
# Data visualization in data science must always have specific purpose and goals. The goals for this project are as follows :-
# <ul>
# <li>To answer tricky questions</li>
# <li>To illustrate trends</li>
# <li>To show data anomalies</li>
# <li>To show outliers</li>
# <li>To show class imbalance</li>
# <li>To understand data distribution</li>
# <li>To understand relationships between various features and target variables</li>
# </ul>

# %%
# For Distribution -  sns.jointplot, sns.kdeplot, sns.distplot
# For Relationship - sns.scattterplot, sns.heatmap, sns.barplot, sns.swarmplot, sns.regplot, sns.lmplot
# For Trends - sns.lineplot

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("dark")

# %% [markdown]
# # Data Cleaning

# %%
iris_data = pd.read_csv('iris.csv')
iris_data.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species  Month  country
# 0               0.2  Iris-setosa    NaN      NaN
# 1               0.2  Iris-setosa    NaN      NaN
# 2               0.2  Iris-setosa    NaN      NaN
# 3               0.2  Iris-setosa    NaN      NaN
# 4               0.2  Iris-setosa    NaN      NaN

# %%
iris_data.drop(['Month', 'country'], axis=1, inplace=True)
iris_data.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
iris_data.columns
# Out:
# Index(['Id', 'Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)',
#        'Petal Width (cm)', 'Species'],
#       dtype='object')

# %%
columns = ['Sepal Length (cm)', 'Sepal Width (cm)', 'Petal Length (cm)', 'Petal Width (cm)']
iris_data[columns] = iris_data[columns].apply(pd.to_numeric, errors='coerce')
iris_data[columns] = iris_data[columns].fillna(iris_data[columns].mean())
iris_data
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
iris_data.dropna(how='all', inplace=True)
iris_data
# Out:
#       Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0      1                5.1               3.5                1.4
# 1      2                4.9               3.0                1.4
# 2      3                4.7               3.2                1.3
# 3      4                4.6               3.1                1.5
# 4      5                5.0               3.6                1.4
# ..   ...                ...               ...                ...
# 145  146                6.7               3.0                5.2
# 146  147                6.3               2.5                5.0
# 147  148                6.5               3.0                5.2
# 148  149                6.2               3.4                5.4
# 149  150                5.9               3.0                5.1
#
#      Petal Width (cm)         Species
# 0                 0.2     Iris-setosa
# 1                 0.2     Iris-setosa
# 2                 0.2     Iris-setosa
# ...

# %%
iris_set = iris_data[iris_data['Species'] == 'Iris-setosa']
iris_ver = iris_data[iris_data['Species'] == 'Iris-versicolor']
iris_vir = iris_data[iris_data['Species'] == 'Iris-virginica']

# %%
iris_set.to_csv('iris_set.csv')
iris_ver.to_csv('iris_ver.csv')
iris_vir.to_csv('iris_vir.csv')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Visualizing for class distribution and imbalance

# %%
plt.figure(figsize=(9, 5))
# KDE plot 
plt.hist(iris_data['Species'])
# Out:
# (array([50.,  0.,  0.,  0.,  0., 50.,  0.,  0.,  0., 50.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(12, 7))
# Histogram 
sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)
# Out:
# C:\Users\sraj2\AppData\Local\Temp\ipykernel_65012\50868604.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=iris_data['Petal Length (cm)'], kde=False)
# <Axes: xlabel='Petal Length (cm)'>

# %% [markdown]
# ######  -> we can see that Petal length has two clusters; one has length of 1-2 cm and other has length of 4 cm to 7 cm

# %% [markdown]
# ### Kernel Density plot

# %%
plt.figure(figsize=(12, 7))
# KDE plot 
sns.kdeplot(data=iris_data['Petal Length (cm)'], fill=True)
# plt.legend()
plt.title("Distribution of Petal Length in Iris Species")
plt.ylabel('Frequency')
plt.xlabel('Petal Length (cm)')
# Out:
# Text(0.5, 0, 'Petal Length (cm)')

# %% [markdown]
# ### 2D KDE plot
#
# ###### In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.

# %%
plt.figure(figsize=(12, 7))
# 2D KDE plot
sns.jointplot(x=iris_data['Petal Length (cm)'], y=iris_data['Sepal Width (cm)'], kind="kde")

# %% [markdown]
# ### Color plots to show key difference between the species and how petal length vary across species

# %%
iris_set_data = pd.read_csv('iris_setosa.csv', index_col="Id")
iris_ver_data = pd.read_csv('iris_versicolor.csv', index_col="Id")
iris_vir_data = pd.read_csv('iris_virginica.csv', index_col="Id")

# %%
plt.figure(figsize=(12, 7))
# Histograms for each species
sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
sns.distplot(a=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", kde=False)
sns.distplot(a=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", kde=False)

# Add title
plt.title("Histogram of Petal Lengths, by Species")

# Force legend to appear
plt.legend()
# Out:
# C:\Users\sraj2\AppData\Local\Temp\ipykernel_65012\380264377.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=iris_set_data['Petal Length (cm)'], label="Iris-setosa", kde=False)
# C:\Users\sraj2\AppData\Local\Temp\ipykernel_65012\380264377.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
df = iris_data

plt.subplots(figsize=(7,6), dpi=100)
sns.distplot( df.loc[df.Species=='Iris-setosa', "Sepal Length (cm)"] , color="dodgerblue", label="Setosa")
sns.distplot( df.loc[df.Species=='Iris-virginica', "Sepal Length (cm)"] , color="orange", label="Virginica")
sns.distplot( df.loc[df.Species=='Iris-versicolor', "Sepal Length (cm)"] , color="deeppink", label="Versicolor")

plt.title('Histogram of Sepal Lengths, by Species')
plt.legend()
# Out:
# C:\Users\sraj2\AppData\Local\Temp\ipykernel_65012\495688912.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( df.loc[df.Species=='Iris-setosa', "Sepal Length (cm)"] , color="dodgerblue", label="Setosa")
# C:\Users\sraj2\AppData\Local\Temp\ipykernel_65012\495688912.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ### Violin Plot
#
# ###### Violin plots are similar to box plots, except that they also show the probability density of the data at different values. These plots include a marker for the median of the data and a box indicating the interquartile range, as in the standard box plots. Overlaid on this box plot is a kernel density estimation. Like box plots, violin plots are used to represent comparison of a variable distribution (or sample distribution) across different "categories".

# %%
plt.subplots(figsize=(7,6), dpi=100)

# Change line width
sns.violinplot( x=df["Species"], y=df["Sepal Length (cm)"], linewidth=5)
#sns.plt.show()
 
# Change width
sns.violinplot( x=df["Species"], y=df["Sepal Length (cm)"], width=0.3)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal Length (cm)'>

# %%
plt.figure(figsize=(12, 7))

# KDE plots for each species
sns.kdeplot(data=iris_set_data['Petal Length (cm)'], label="Iris-setosa", fill=True)
sns.kdeplot(data=iris_ver_data['Petal Length (cm)'], label="Iris-versicolor", fill=True)
sns.kdeplot(data=iris_vir_data['Petal Length (cm)'], label="Iris-virginica", fill=True)

# Add title
plt.title("Distribution of Petal Lengths, by Species")

# Force legend to appear
plt.legend()

# %% [markdown]
# ### Pairplots
#
# ###### To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function. This creates a matrix of axes and shows the relationship for each pair of columns in a DataFrame. By default, it also draws the univariate distribution of each variable on the diagonal Axes.

# %%
iris=iris_data.drop(['Id'], axis=1)
sns.pairplot(iris, hue="Species");

# %% [markdown]
# # Thank You !!
